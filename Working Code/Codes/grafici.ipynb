# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### SMARTPHONES
#
# THE FOLLOWING PLOT SHOWS THE PERFORMANCE OF EACH MODEL

# %%
k_fold_completo = [560, 433, 368, 351]
k_fold_postcovid = [541, 417, 357, 339]
modello_finale = [314, 306, 327, 341]

smartphones = pd.DataFrame({'K-FOLD (ALL DATA)':k_fold_completo,
                    'K-FOLD (NO 2020)':k_fold_postcovid,
                    'FINAL MODEL':modello_finale},
                    index = ['Benchmark', 'Linear Regression', 'Random Forest', 'XGBoost'])

colors = ['#9467bd', '#57658f', '#ff9933']
fig, ax = plt.subplots(figsize=(8, 4)) 
smartphones.plot(kind='bar', ax=ax, color = colors) 
plt.xlabel('MODELS', fontsize = 12, fontstyle='italic')
plt.xticks(rotation=0)
plt.ylabel('RMSE', fontsize = 12, fontstyle='italic')
plt.title('RMSE comparison among models for Smartphone', fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend(title='Legend', fontsize = 8)
ax.set_ylim(0, smartphones.max().max()+50)
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)

for index, value in enumerate(smartphones['FINAL MODEL']):
    if value == min(smartphones['FINAL MODEL']):
        plt.text(index + 0.1, value + 10, str(value), ha='left', va='bottom', fontsize=8)

plt.tight_layout()
#plt.savefig('/Users/vincenzocamerlengo/Desktop/Data Science in Action/Unieuro Dataset-20240305/grafici/smart.png', dpi=900)
plt.show()

# %% [markdown]
# ### PC
#
# THE FOLLOWING PLOT SHOWS THE PERFORMANCE OF EACH MODEL

# %%
k_fold_completo = [420, 283, 260, 258]
k_fold_postcovid = [406, 270, 241, 240]
modello_finale = [257, 178, 164, 162]

pc = pd.DataFrame({'K-FOLD (ALL DATA)':k_fold_completo,
                    'K-FOLD (NO 2020)':k_fold_postcovid,
                    'FINAL MODEL':modello_finale},
                    index = ['Benchmark', 'Linear Regression', 'Random Forest', 'XGBoost'])

colors = ['#9467bd', '#57658f', '#ff9933']
fig, ax = plt.subplots(figsize=(8, 4)) 
pc.plot(kind='bar', ax=ax, color = colors) 
plt.xlabel('MODELS', fontsize = 12, fontstyle='italic')
plt.xticks(rotation=0)
plt.ylabel('RMSE', fontsize = 12, fontstyle='italic')
plt.title('RMSE comparison among models for PC', fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend(title='Legend', fontsize = 8)
ax.set_ylim(0, pc.max().max()+50)
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)

for index, value in enumerate(pc['FINAL MODEL']):
    if value == min(pc['FINAL MODEL']):
        plt.text(index + 0.1, value + 10, str(value), ha='left', va='bottom', fontsize=8)

plt.tight_layout()
#plt.savefig('/Users/vincenzocamerlengo/Desktop/Data Science in Action/Unieuro Dataset-20240305/grafici/pc.png', dpi=900)
plt.show()

# %% [markdown]
# ### WASH
#
# THE FOLLOWING PLOT SHOWS THE PERFORMANCE OF EACH MODEL

# %%
k_fold_completo = [380, 226, 194, 195]
k_fold_postcovid = [374, 212, 188, 181]
modello_finale = [244, 160, 145, 159]

wash = pd.DataFrame({'K-FOLD (ALL DATA)':k_fold_completo,
                    'K-FOLD (NO 2020)':k_fold_postcovid,
                    'FINAL MODEL':modello_finale},
                    index = ['Benchmark', 'Linear Regression', 'Random Forest', 'XGBoost'])

colors = ['#9467bd', '#57658f', '#ff9933']
fig, ax = plt.subplots(figsize=(8, 4)) 
wash.plot(kind='bar', ax=ax, color = colors) 
plt.xlabel('MODELS', fontsize = 12, fontstyle='italic')
plt.xticks(rotation=0)
plt.ylabel('RMSE', fontsize = 12, fontstyle='italic')
plt.title('RMSE comparison among models for Wash', fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend(title='Legend', fontsize = 8)
ax.set_ylim(0, wash.max().max()+50)
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)

for index, value in enumerate(wash['FINAL MODEL']):
    if value == min(wash['FINAL MODEL']):
        plt.text(index + 0.1, value + 10, str(value), ha='left', va='bottom', fontsize=8)

plt.tight_layout()
#plt.savefig('/Users/vincenzocamerlengo/Desktop/Data Science in Action/Unieuro Dataset-20240305/grafici/wash.png', dpi=900)
plt.show()

# %% [markdown]
# ### CORE_WEAR
#
# THE FOLLOWING PLOT SHOWS THE PERFORMANCE OF EACH MODEL

# %%
k_fold_completo = [301, 232, 186, 210]
k_fold_postcovid = [299, 220, 187, 188]
modello_finale = [150, 141, 131, 127]

core_wear = pd.DataFrame({'K-FOLD (ALL DATA)':k_fold_completo,
                    'K-FOLD (NO 2020)':k_fold_postcovid,
                    'FINAL MODEL':modello_finale},
                    index = ['Benchmark', 'Linear Regression', 'Random Forest', 'XGBoost'])

colors = ['#9467bd', '#57658f', '#ff9933']
fig, ax = plt.subplots(figsize=(8, 4)) 
core_wear.plot(kind='bar', ax=ax, color = colors) 
plt.xlabel('MODELS', fontsize = 12, fontstyle='italic')
plt.xticks(rotation=0)
plt.ylabel('RMSE', fontsize = 12, fontstyle='italic')
plt.title('RMSE comparison among models for CORE_WEAR', fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend(title='Legend', fontsize = 8)
ax.set_ylim(0, core_wear.max().max()+50)
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)

for index, value in enumerate(core_wear['FINAL MODEL']):
    if value == min(core_wear['FINAL MODEL']):
        plt.text(index + 0.1, value + 10, str(value), ha='left', va='bottom', fontsize=8)

plt.tight_layout()
#plt.savefig('/Users/vincenzocamerlengo/Desktop/Data Science in Action/Unieuro Dataset-20240305/grafici/core.png', dpi=900)
plt.show()

# %% [markdown]
# ### TV
#
# THE FOLLOWING PLOT SHOWS THE PERFORMANCE OF EACH MODEL

# %%
k_fold_completo = [420, 312, 302, 301]
k_fold_postcovid = [399, 299, 296, 293]
modello_finale = [176, 221, 202, 174]

tv = pd.DataFrame({'K-FOLD (ALL DATA)':k_fold_completo,
                    'K-FOLD (NO 2020)':k_fold_postcovid,
                    'FINAL MODEL':modello_finale},
                    index = ['Benchmark', 'Linear Regression', 'Random Forest', 'XGBoost'])

colors = ['#9467bd', '#57658f', '#ff9933']
fig, ax = plt.subplots(figsize=(8, 4)) 
tv.plot(kind='bar', ax=ax, color = colors) 
plt.xlabel('MODELS', fontsize = 12, fontstyle='italic')
plt.xticks(rotation=0)
plt.ylabel('RMSE', fontsize = 12, fontstyle='italic')
plt.title('RMSE comparison among models for TV', fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend(title='Legend', fontsize = 8)
ax.set_ylim(0, tv.max().max()+50)
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)

for index, value in enumerate(tv['FINAL MODEL']):
    if value == min(tv['FINAL MODEL']):
        plt.text(index + 0.1, value + 10, str(value), ha='left', va='bottom', fontsize=8)

plt.tight_layout()
#plt.savefig('/Users/vincenzocamerlengo/Desktop/Data Science in Action/Unieuro Dataset-20240305/grafici/tv.png', dpi=900)
plt.show()

# %% [markdown]
# ## MONTH REDD

# %%
def nomi_campagna(df):
    
    pattern = ['BACK TO SCHOOL', 'BACK TO SCHOOL 1', 'BACK TO SCHOOL 2', 'Back to School', 'Back to School continua']
    df.NOME_CAMPAGNA.replace(pattern, 'back_to_school', inplace = True)

    pattern = ['BASKET', 'BASKET INTERESSI ZERO + TRADE IN', 'BASKET MARZO', 'BASKET SCONTI APRILE', 'BASKET SCONTI FEBBRAIO', 'BASKET SCONTI FEBBRAIO 2']
    df.NOME_CAMPAGNA.replace(pattern, 'basket', inplace = True)

    pattern = ['BLACK FRIDAY - EPISODIO 1', 'BLACK FRIDAY - EPISODIO 3', 'BLACK FRIDAY EP.0', 'BLACK FRIDAY EP.1',
            'BLACK FRIDAY EP.2', 'Bastard Black Friday', 'Black Addams Friday', 'Black Addams Friday Continua', 'Black Rock Friday',
            'Change Black Friday', 'Change Black Friday 2', 'Change Black Friday Gran Finale', 'Change Black Friday', 
            'Manà Manà Black Friday', 'Manà Manà Black Friday continua','Manà Manà Black Friday continua 2', 'Manà Manà Black Friday continua 3',
            'BF 2 - TEMPTATION BLACK FRIDAY', 'SUMMER BLACK FRIDAY 2', 'SUMMER BLACK FRIDAY 1', 'Summer Black Friday', 'Summer Black Friday 2']
    df.NOME_CAMPAGNA.replace(pattern, 'black_friday', inplace = True)

    pattern = ['Continua il Fuoritutto Gennaio', 'FUORITUTTO 1','FUORITUTTO 1 AGOSTO','FUORITUTTO 2','FUORITUTTO 2 AGOSTO','Fuoritutto',
            'Fuoritutto 1','Fuoritutto 1 Summer','Fuoritutto 2','Fuoritutto 2 Summer','Fuoritutto Continua','Fuoritutto Gennaio','Fuoritutto Inverno 1',
            'Fuoritutto Inverno 2','Fuoritutto1 E','Fuoritutto1 W','Fuoritutto2 E','Fuoritutto2 W','Il Vero Fuoritutto', 'Il Vero Fuoritutto continua']
    df.NOME_CAMPAGNA.replace(pattern, 'fuori_tutto', inplace = True)

    pattern = ['PASSIONE CASA','PASSIONE CASA - BUONI INNOVAZIONE','Passione Casa','Passione Casa - Hitachi Abbinato',
            'Passione Casa - Kitchenaid Abbinato','Passione Casa Settembre','Passione casa']
    df.NOME_CAMPAGNA.replace(pattern, 'passione_casa', inplace = True)

    pattern = ['SOTTOCOSTO', 'SOTTOCOSTO LUGLIO', 'SOTTOCOSTO NATALE', 'Sottoprezzo','Sottocosto Natale','Sottocosto Luglio','Sottocosto Giugno',
            'Sottocosto Dicembre','Sottocosto Autunno','Sottocosto 2', 'Sottocosto', "Sotto Costo un mare d'offerte"]
    df.NOME_CAMPAGNA.replace(pattern, 'sottocosto', inplace = True)

    pattern = ['Happy Sconti - Tasso 0', 'Tasso 0 Risparmio Vero',"Tasso 0 - Sconti d'Estate",'Tasso 0 - Sconti', 'TASSO ZERO - IT TRADE IN','TASSO ZERO',
            'TASSO 0 - SPECIALE PULIZIA'," Solo il Meglio? E' scontato - Tasso Zero", 'Settembre di Sconti - Tasso 0', 'UN MARE DI SCONTI A TASSO ZERO',
            "Sconti di Settembre Tasso Zero", "Sconti d'Estate a Tasso Zero", "Sconti che Sognavi - Tasso Zero", 'SCONTI DI MAGGIO A TASSO ZERO', 
            'Risparmio Vero Tasso Zero', 'Natale Tasso Zero', 'NATALE A TASSO ZERO','Mare di Sconti - Tasso 0','Happy Sconti - Tasso 0',
            "Solo il Meglio? E' scontato - Tasso Zero"]
    df.NOME_CAMPAGNA.replace(pattern, 'tasso_zero', inplace = True)

    pattern = ['Natalissimi','Halloween Days', 'Primavera di Sconti', 'Fioriscono gli Sconti', 'Collezione primavera', 'CALENDARIO AVVENTO', 'HALLOWEEN WEEK',
            'Summer Days', 'I Natalissimi', 'Buon anno con Unieuro']
    df.NOME_CAMPAGNA.replace(pattern, 'special_days', inplace = True)

    pattern = ['Flyer Volo', 'VOLAGRATIS', 'Vola con noi']
    df.NOME_CAMPAGNA.replace(pattern, 'fly', inplace = True)

    pattern = ['BIKE IN REGALO', 'Flyer Bike', 'Promo Bike WOW']
    df.NOME_CAMPAGNA.replace(pattern, 'bike', inplace = True)

    pattern = ['Sconti Fino Al 50 - Focus Ped', 'SECONDO AL 50', 'Flyer Secondo Al 50%', 'Sconti Fino Al 50 - Focus Bianco']
    df.NOME_CAMPAGNA.replace(pattern, '50%', inplace = True)

    pattern = ['VOLANTINO BUONI','Ogni momento è buono','TRADE IN PC','Lovely Days',
            'Unieuro ti regala la Mia','Amore al primo acquisto', 'Tanto ti dà Tanto','Cookeo connect',
            'Se Vuoi Puoi','Tra tante offerte la tua','Se Vuoi Puoi 2','E amore al primo acquisto','Noi ci siamo', 'Sconti batticuore']

    df.NOME_CAMPAGNA.replace(pattern, 'other', inplace = True)

    df['SCONTO_PERC_MEDIO_NOME_CAMPAGNA'] = df.groupby('NOME_CAMPAGNA')['SCONTO_PERC'].transform('mean')

# %% [markdown]
# ### EXAMPLE ON PRODUCT GROUP - PC

# %%
pc = pd.read_csv('./Working Code/Datasets/pc.csv') 
pc.drop('Unnamed: 0', axis=1, inplace=True)

pc['DATA_INIZIO'] = pd.to_datetime(pc['DATA_INIZIO'])
pc['DATA_FINE'] = pd.to_datetime(pc['DATA_FINE'])

pc['Month'] = pc['DATA_INIZIO'].dt.month
pc['Month'] = pc['Month'].astype(str)

pc['Year'] = pc['DATA_INIZIO'].dt.year
pc_escluso2023 = pc[pc['Year'] < 2023]
pc['Year'].replace([2018, 2019], 'PRE_COVID', inplace=True)
pc['Year'].replace([2020, 2021], 'COVID', inplace=True)
pc['Year'].replace([2022, 2023], 'POST_COVID', inplace=True)

nomi_campagna(pc)

# %%
monthly_revenue = pc_escluso2023.groupby('Month')['FATTURATO_storico'].sum()
monthly_revenue = monthly_revenue.sort_index(key=lambda x: x.astype(int))
def revenue (series):
    x = series['1']
    for i in range(len(series.index) - 1):
        series[i] = series[i+1]
    series['12'] = x
    return series
revenue(monthly_revenue)
# Out:
# Month
# 1      6988198.95
# 2     15551214.03
# 3      9349693.69
# 4     13233422.54
# 5      9542244.48
# 6     16209906.79
# 7     14819891.61
# 8     13942397.06
# 9      7421727.40
# 10    14147637.15
# 11    10680566.47
# 12    14329907.21
# Name: FATTURATO_storico, dtype: float64

# %%
plt.figure(figsize=(10, 6))
colors = ['#8B0000' if m in [0, 2, 4, 8] else '#B8860B' if m in [3, 7, 10] else '#006400' for m in range(12)]
monthly_revenue.plot(kind='bar', color=colors)
plt.title('Monthly Cumulative Revenue for PC', fontweight='bold')
plt.xlabel('Month', fontsize = 12, fontstyle='italic')
plt.ylabel('Total Revenue', fontsize = 12, fontstyle='italic')
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(range(0, 12), months, rotation=0) 
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
legend_elements = [
    plt.Line2D([0], [0], color='#8B0000', lw=4, label='Low Profitability'),
    plt.Line2D([0], [0], color='#B8860B', lw=4, label='Medium Profitability'),
    plt.Line2D([0], [0], color='#006400', lw=4, label='High Profitability')
]
plt.legend(handles=legend_elements)
plt.text(-1.555, 9300000, 'First Quartile', rotation=0, verticalalignment='bottom', fontsize = 6)
plt.text(-1.555, 13300000, 'Third Quartile', rotation=0, verticalalignment='bottom', fontsize = 6)
plt.tight_layout()
#plt.savefig('/Users/vincenzocamerlengo/Desktop/Data Science in Action/Unieuro Dataset-20240305/grafici/month_redd.png', dpi=900)
plt.show()

# %%
monthly_revenue.describe()
# Out:
# count    1.200000e+01
# mean     1.218473e+07
# std      3.220616e+06
# min      6.988199e+06
# 25%      9.494107e+06
# 50%      1.358791e+07
# 75%      1.445240e+07
# max      1.620991e+07
# Name: FATTURATO_storico, dtype: float64

# %% [markdown]
# ## PREDICTIONS AND FEATURE IMPORTANCE

# %% [markdown]
# ### SMARTPHONE

# %%
smartphones = pd.read_csv('./Working Code/Datasets/smartphones1.csv') 
smartphones['DATA_INIZIO'] = pd.to_datetime(smartphones['DATA_INIZIO'])
smartphones['Year'] = smartphones['DATA_INIZIO'].dt.year
smartphones = smartphones[smartphones['Year'] != 2020].reset_index()
smartphones.drop('index', axis=1, inplace=True)

X = smartphones[['PREZZO_PROMO', 'PREZZO_LISTINO', 'STOCK_PZ',
                 'TIPOLOGIA_PRODOTTO', 'SCONTO_PERC', 'KPI_1',
                 'KPI_2', 'KPI_3', 'KPI_4', 'KPI_5', 'QTA_storico',
                 'FATTURATO_storico', 'DURATA_VOLANTINO_IN_GIORNI',
                 'DISPLAY_SIZE', 'OPERATOR', 'NUMBER_OF_SIM',
                 'CAPACITY', 'GENERATION', 'OPERATING_SYST', 'Month_Redditivity',
                 'SCONTO_PERC_MEDIO_VOLANTINO', 'SCONTO_PERC_MEDIO_NOME_CAMPAGNA', 'DATA_INIZIO']]

y = smartphones[['QTA', 'DATA_INIZIO']]

from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse = False)
oheTransform = ohe.fit_transform(X[['TIPOLOGIA_PRODOTTO', 'OPERATOR']])
oheTransform = pd.DataFrame(oheTransform, columns=ohe.get_feature_names_out())

final_df = pd.concat([X, oheTransform], axis=1)

final_df = final_df.drop(['TIPOLOGIA_PRODOTTO', 'OPERATOR'], axis = 1)

X_train = final_df[~(((final_df['DATA_INIZIO'].dt.month == 8) | (final_df['DATA_INIZIO'].dt.month == 9) | (final_df['DATA_INIZIO'].dt.month == 10)) & (final_df['DATA_INIZIO'].dt.year == 2023))]
X_test = final_df[((final_df['DATA_INIZIO'].dt.month == 8) | (final_df['DATA_INIZIO'].dt.month == 9) | (final_df['DATA_INIZIO'].dt.month == 10)) & (final_df['DATA_INIZIO'].dt.year == 2023)]

X_train.drop('DATA_INIZIO', axis=1, inplace=True)
X_test.drop('DATA_INIZIO', axis=1, inplace=True)

y_train = y[~(((y['DATA_INIZIO'].dt.month == 8) | (y['DATA_INIZIO'].dt.month == 9) | (y['DATA_INIZIO'].dt.month == 10)) & (y['DATA_INIZIO'].dt.year == 2023))]
y_test = y[((y['DATA_INIZIO'].dt.month == 8) | (y['DATA_INIZIO'].dt.month == 9) | (y['DATA_INIZIO'].dt.month == 10)) & (y['DATA_INIZIO'].dt.year == 2023)]
y_train.drop('DATA_INIZIO', axis=1, inplace=True)
y_test.drop('DATA_INIZIO', axis=1, inplace=True)

y_train = y_train.values
y_test = y_test.values

# %%
from sklearn.preprocessing import StandardScaler
column_names = X_train.columns.tolist()
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

from sklearn.linear_model import LinearRegression
classifier = LinearRegression()
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)
y_pred = np.where(y_pred < 0, 0, y_pred)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f'RMSE = {rmse}')
# Out:
# RMSE = 306.9776763954178

# %%
var=[]
coeff=[]
for feature, coef in zip(column_names, classifier.coef_.tolist()[0]):
    var.append(feature)
    coeff.append(coef)
x = pd.DataFrame({'variabili':var, 'coefficienti':coeff})
x['coefficienti'] = x['coefficienti'].abs()
x['coefficienti'] = x['coefficienti']/x['coefficienti'].max()
x.sort_values(by='coefficienti', ascending=False, inplace=True)
x.reset_index(inplace=True)
x.drop('index', axis=1, inplace=True)

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
plt.scatter(y_test.flatten(), y_pred.flatten(), color='#ff9933')
plt.title('Predictions', fontweight='bold')
plt.xlabel('True Values', fontsize = 12, fontstyle='italic')
plt.ylabel('Predicted Values', fontsize = 12, fontstyle='italic')
formatter = ticker.StrMethodFormatter('{x:,.0f}')
plt.gca().xaxis.set_major_formatter(formatter)
formatter = ticker.StrMethodFormatter('{x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)
plt.xlim(0, max(y_test.max(), y_pred.max()) * 1.1)
plt.ylim(0, max(y_test.max(), y_pred.max()) * 1.1)
plt.plot([0, y_test.max()], [0, y_test.max()], '#57658f', lw=2)

plt.subplot(1, 2, 2)
colors = ['#57658f' if i not in [7, 10, 15] else '#ff9933' for i in range(len(x.head(16)))]
sns.barplot(x.head(16), y='variabili', x='coefficienti', orient='h', palette=colors)
plt.xlabel('Importance', fontsize = 12, fontstyle='italic')
plt.ylabel('Features', fontsize = 12, fontstyle='italic')
plt.title('Feature Importance', fontweight='bold')
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
custom_legend = plt.Line2D([], [], color='#ff9933', marker='s', markersize=10, linestyle='None', label='Our Variables')
plt.legend(handles=[custom_legend], loc='lower right', fontsize=10)

plt.tight_layout()
#plt.savefig('/Users/vincenzocamerlengo/Desktop/Data Science in Action/Unieuro Dataset-20240305/grafici/smart_pred.png', dpi=900)
plt.show()

# %% [markdown]
# ### PC

# %%
pc = pd.read_csv('./Working Code/Datasets/pc1.csv') 
pc['DATA_INIZIO'] = pd.to_datetime(pc['DATA_INIZIO'])
pc['Year'] = pc['DATA_INIZIO'].dt.year
pc = pc[pc['Year'] != 2020].reset_index()
pc.drop('index', axis=1, inplace=True)

X = pc[['PREZZO_PROMO', 'PREZZO_LISTINO', 'STOCK_PZ',
        'TIPOLOGIA_PRODOTTO','SCONTO_PERC', 'KPI_1',
        'KPI_2', 'KPI_3', 'KPI_4', 'KPI_5', 'QTA_storico',
        'FATTURATO_storico', 'DURATA_VOLANTINO_IN_GIORNI',
        'STORAGE_GB', 'RAM_GB', 'DISPLAY_SIZE', 'CONVERTIBLE',
        'SCONTO_PERC_MEDIO_VOLANTINO', 'VERSION_NOT_DEFINED',
        'VERSION_INTEL', 'VERSION_APPLE', 'VERSION_RAD',
        'VERSION_GEF', 'QUALITY_VERSION', 'QUALITY_PROCESSOR',
        'Month_Redditivity', 'SCONTO_PERC_MEDIO_NOME_CAMPAGNA', 'DATA_INIZIO']]
y = pc[['QTA', 'DATA_INIZIO']]

from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse = False)
oheTransform = ohe.fit_transform(X[['TIPOLOGIA_PRODOTTO']])
oheTransform = pd.DataFrame(oheTransform, columns=ohe.get_feature_names_out())

final_df = pd.concat([X, oheTransform], axis=1)

final_df = final_df.drop(['TIPOLOGIA_PRODOTTO'], axis = 1)

X_train = final_df[~(((final_df['DATA_INIZIO'].dt.month == 8) | (final_df['DATA_INIZIO'].dt.month == 9) | (final_df['DATA_INIZIO'].dt.month == 10)) & (final_df['DATA_INIZIO'].dt.year == 2023))]
X_test = final_df[((final_df['DATA_INIZIO'].dt.month == 8) | (final_df['DATA_INIZIO'].dt.month == 9) | (final_df['DATA_INIZIO'].dt.month == 10)) & (final_df['DATA_INIZIO'].dt.year == 2023)]

X_train.drop('DATA_INIZIO', axis=1, inplace=True)
X_test.drop('DATA_INIZIO', axis=1, inplace=True)

y_train = y[~(((y['DATA_INIZIO'].dt.month == 8) | (y['DATA_INIZIO'].dt.month == 9) | (y['DATA_INIZIO'].dt.month == 10)) & (y['DATA_INIZIO'].dt.year == 2023))]
y_test = y[((y['DATA_INIZIO'].dt.month == 8) | (y['DATA_INIZIO'].dt.month == 9) | (y['DATA_INIZIO'].dt.month == 10)) & (y['DATA_INIZIO'].dt.year == 2023)]
y_train.drop('DATA_INIZIO', axis=1, inplace=True)
y_test.drop('DATA_INIZIO', axis=1, inplace=True)

y_train = y_train.values
y_test = y_test.values

column_names = X_train.columns.tolist()

# %%
hyperparameters = {'subsample': 0.9, 'n_estimators': 400, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.01, 'gamma': 0.2, 'colsample_bytree': 1.0}

import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error

xgbr = xgb.XGBRegressor(random_state=69, **hyperparameters)
xgbr.fit(X_train, y_train)
y_pred = xgbr.predict(X_test)
y_pred = np.where(y_pred < 0, 0, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'RMSE = {rmse}')
# Out:
# RMSE = 162.3577202925557

# %%
var=[]
coeff=[]
for feature, coef in zip(column_names, xgbr.feature_importances_):
    var.append(feature)
    coeff.append(coef)
x = pd.DataFrame({'variabili':var, 'coefficienti':coeff})
x['coefficienti'] = x['coefficienti'].abs()
x['coefficienti'] = x['coefficienti']/x['coefficienti'].max()
x.sort_values(by='coefficienti', ascending=False, inplace=True)
x.reset_index(inplace=True)
x.drop('index', axis=1, inplace=True)

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
plt.scatter(y_test.flatten(), y_pred, color='#ff9933')
plt.title('Predictions', fontweight='bold')
plt.xlabel('True Values', fontsize = 12, fontstyle='italic')
plt.ylabel('Predicted Values', fontsize = 12, fontstyle='italic')
formatter = ticker.StrMethodFormatter('{x:,.0f}')
plt.gca().xaxis.set_major_formatter(formatter)
formatter = ticker.StrMethodFormatter('{x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)
plt.xlim(0, max(y_test.max(), y_pred.max()) * 1.1)
plt.ylim(0, max(y_test.max(), y_pred.max()) * 1.1)
plt.plot([0, y_test.max()], [0, y_test.max()], '#57658f', lw=2)

plt.subplot(1, 2, 2)
colors = ['#57658f' if i not in [7, 8, 10] else '#ff9933' for i in range(len(x.head(16)))]
sns.barplot(x.head(16), y='variabili', x='coefficienti', orient='h', palette=colors)
plt.xlabel('Importance', fontsize = 12, fontstyle='italic')
plt.ylabel('Features', fontsize = 12, fontstyle='italic')
plt.title('Feature Importance', fontweight='bold')
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
custom_legend = plt.Line2D([], [], color='#ff9933', marker='s', markersize=10, linestyle='None', label='Our Variables')
plt.legend(handles=[custom_legend], loc='lower right', fontsize=10)

plt.tight_layout()
#plt.savefig('/Users/vincenzocamerlengo/Desktop/Data Science in Action/Unieuro Dataset-20240305/grafici/pc_pred.png', dpi=900)
plt.show()

# %% [markdown]
# ### WASH

# %%
wash = pd.read_csv('./Working Code/Datasets/wash1.csv') 
wash['DATA_INIZIO'] = pd.to_datetime(wash['DATA_INIZIO'])
wash['Year'] = wash['DATA_INIZIO'].dt.year
wash = wash[wash['Year'] != 2020].reset_index()
wash.drop('index', axis=1, inplace=True)
X = wash[['PREZZO_PROMO', 'PREZZO_LISTINO', 'STOCK_PZ',
        'TIPOLOGIA_PRODOTTO','SCONTO_PERC', 'KPI_1',
        'KPI_2', 'KPI_3', 'KPI_4', 'KPI_5', 'QTA_storico',
        'FATTURATO_storico', 'DURATA_VOLANTINO_IN_GIORNI',
        'TYPE', 'TOPLOADING', 'LOADING_KG', 'ENERGY_CLASS',
        'DEPTH_CM>48', 'SMART_CONNECT', 'SCONTO_PERC_MEDIO_VOLANTINO', 'Month_Redditivity',
        'SCONTO_PERC_MEDIO_NOME_CAMPAGNA', 'DATA_INIZIO']]
y = wash[['QTA', 'DATA_INIZIO']]

from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse = False)
oheTransform = ohe.fit_transform(X[['TIPOLOGIA_PRODOTTO']])
oheTransform = pd.DataFrame(oheTransform, columns=ohe.get_feature_names_out())

final_df = pd.concat([X, oheTransform], axis=1)

final_df = final_df.drop(['TIPOLOGIA_PRODOTTO'], axis = 1)

X_train = final_df[~(((final_df['DATA_INIZIO'].dt.month == 8) | (final_df['DATA_INIZIO'].dt.month == 9) | (final_df['DATA_INIZIO'].dt.month == 10)) & (final_df['DATA_INIZIO'].dt.year == 2023))]
X_test = final_df[((final_df['DATA_INIZIO'].dt.month == 8) | (final_df['DATA_INIZIO'].dt.month == 9) | (final_df['DATA_INIZIO'].dt.month == 10)) & (final_df['DATA_INIZIO'].dt.year == 2023)]

X_train.drop('DATA_INIZIO', axis=1, inplace=True)
X_test.drop('DATA_INIZIO', axis=1, inplace=True)

y_train = y[~(((y['DATA_INIZIO'].dt.month == 8) | (y['DATA_INIZIO'].dt.month == 9) | (y['DATA_INIZIO'].dt.month == 10)) & (y['DATA_INIZIO'].dt.year == 2023))]
y_test = y[((y['DATA_INIZIO'].dt.month == 8) | (y['DATA_INIZIO'].dt.month == 9) | (y['DATA_INIZIO'].dt.month == 10)) & (y['DATA_INIZIO'].dt.year == 2023)]
y_train.drop('DATA_INIZIO', axis=1, inplace=True)
y_test.drop('DATA_INIZIO', axis=1, inplace=True)

y_train = y_train.values
y_test = y_test.values
column_names = X_train.columns.tolist()

hyperparameters = {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 40, 'bootstrap': False}

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

rfr = RandomForestRegressor(random_state=69, **hyperparameters)
rfr.fit(X_train, y_train)
y_pred = rfr.predict(X_test)
y_pred = np.where(y_pred < 0, 0, y_pred)

mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f'RMSE = {rmse}')
# Out:
# RMSE = 146.05738918334802

# %%
var=[]
coeff=[]
for feature, coef in zip(column_names, rfr.feature_importances_):
    var.append(feature)
    coeff.append(coef)
x = pd.DataFrame({'variabili':var, 'coefficienti':coeff})
x['coefficienti'] = x['coefficienti'].abs()
x['coefficienti'] = x['coefficienti']/x['coefficienti'].max()
x.sort_values(by='coefficienti', ascending=False, inplace=True)
x.reset_index(inplace=True)
x.drop('index', axis=1, inplace=True)

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
plt.scatter(y_test.flatten(), y_pred, color='#ff9933')
plt.title('Predictions', fontweight='bold')
plt.xlabel('True Values', fontsize = 12, fontstyle='italic')
plt.ylabel('Predicted Values', fontsize = 12, fontstyle='italic')
formatter = ticker.StrMethodFormatter('{x:,.0f}')
plt.gca().xaxis.set_major_formatter(formatter)
formatter = ticker.StrMethodFormatter('{x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)
plt.xlim(0, max(y_test.max(), y_pred.max()) * 1.1)
plt.ylim(0, max(y_test.max(), y_pred.max()) * 1.1)
plt.plot([0, y_test.max()], [0, y_test.max()], '#57658f', lw=2)

plt.subplot(1, 2, 2)
colors = ['#57658f' if i not in [3, 5, 14] else '#ff9933' for i in range(len(x.head(16)))]
sns.barplot(x.head(16), y='variabili', x='coefficienti', orient='h', palette=colors)
plt.xlabel('Importance', fontsize = 12, fontstyle='italic')
plt.ylabel('Features', fontsize = 12, fontstyle='italic')
plt.title('Feature Importance', fontweight='bold')
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
custom_legend = plt.Line2D([], [], color='#ff9933', marker='s', markersize=10, linestyle='None', label='Our Variables')
plt.legend(handles=[custom_legend], loc='lower right', fontsize=10)

plt.tight_layout()
#plt.savefig('/Users/vincenzocamerlengo/Desktop/Data Science in Action/Unieuro Dataset-20240305/grafici/wash_pred.png', dpi=900)
plt.show()

# %% [markdown]
# ### CORE_WEAR

# %%
core_wear = pd.read_csv('./Working Code/Datasets/core_wear1.csv')
core_wear['DATA_INIZIO'] = pd.to_datetime(core_wear['DATA_INIZIO'])
core_wear['Year'] = core_wear['DATA_INIZIO'].dt.year
core_wear = core_wear[core_wear['Year'] != 2020].reset_index()
core_wear.drop('index', axis=1, inplace=True)

X = core_wear[['PREZZO_PROMO', 'PREZZO_LISTINO', 'STOCK_PZ',
        'TIPOLOGIA_PRODOTTO','SCONTO_PERC', 'KPI_1',
        'KPI_2', 'KPI_3', 'KPI_4', 'KPI_5', 'QTA_storico',
        'FATTURATO_storico', 'DURATA_VOLANTINO_IN_GIORNI',
        'DISPLAY_QUALITY', 'BLUETOOTH', 'WIFI', 'DISPLAY_SIZE',
        'SCONTO_PERC_MEDIO_VOLANTINO', 'Month_Redditivity', 'SCONTO_PERC_MEDIO_NOME_CAMPAGNA', 'DATA_INIZIO']]
y = core_wear[['QTA', 'DATA_INIZIO']]

from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse = False)
oheTransform = ohe.fit_transform(X[['TIPOLOGIA_PRODOTTO']])
oheTransform = pd.DataFrame(oheTransform, columns=ohe.get_feature_names_out())

final_df = pd.concat([X, oheTransform], axis=1)

final_df = final_df.drop(['TIPOLOGIA_PRODOTTO'], axis = 1)

X_train = final_df[~(((final_df['DATA_INIZIO'].dt.month == 8) | (final_df['DATA_INIZIO'].dt.month == 9) | (final_df['DATA_INIZIO'].dt.month == 10)) & (final_df['DATA_INIZIO'].dt.year == 2023))]
X_test = final_df[((final_df['DATA_INIZIO'].dt.month == 8) | (final_df['DATA_INIZIO'].dt.month == 9) | (final_df['DATA_INIZIO'].dt.month == 10)) & (final_df['DATA_INIZIO'].dt.year == 2023)]

X_train.drop('DATA_INIZIO', axis=1, inplace=True)
X_test.drop('DATA_INIZIO', axis=1, inplace=True)

y_train = y[~(((y['DATA_INIZIO'].dt.month == 8) | (y['DATA_INIZIO'].dt.month == 9) | (y['DATA_INIZIO'].dt.month == 10)) & (y['DATA_INIZIO'].dt.year == 2023))]
y_test = y[((y['DATA_INIZIO'].dt.month == 8) | (y['DATA_INIZIO'].dt.month == 9) | (y['DATA_INIZIO'].dt.month == 10)) & (y['DATA_INIZIO'].dt.year == 2023)]
y_train.drop('DATA_INIZIO', axis=1, inplace=True)
y_test.drop('DATA_INIZIO', axis=1, inplace=True)

y_train = y_train.values
y_test = y_test.values
column_names = X_train.columns.tolist()

hyperparameters = {'subsample': 0.6, 'n_estimators': 500, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 0.9}

import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error

xgbr = xgb.XGBRegressor(random_state=69, **hyperparameters)
xgbr.fit(X_train, y_train)
y_pred = xgbr.predict(X_test)
y_pred = np.where(y_pred < 0, 0, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'RMSE = {rmse}')
# Out:
# RMSE = 129.49870890832284

# %%
var=[]
coeff=[]
for feature, coef in zip(column_names, xgbr.feature_importances_):
    var.append(feature)
    coeff.append(coef)
x = pd.DataFrame({'variabili':var, 'coefficienti':coeff})
x['coefficienti'] = x['coefficienti'].abs()
x['coefficienti'] = x['coefficienti']/x['coefficienti'].max()
x.sort_values(by='coefficienti', ascending=False, inplace=True)
x.reset_index(inplace=True)
x.drop('index', axis=1, inplace=True)

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
plt.scatter(y_test.flatten(), y_pred, color='#ff9933')
plt.title('Predictions', fontweight='bold')
plt.xlabel('True Values', fontsize = 12, fontstyle='italic')
plt.ylabel('Predicted Values', fontsize = 12, fontstyle='italic')
formatter = ticker.StrMethodFormatter('{x:,.0f}')
plt.gca().xaxis.set_major_formatter(formatter)
formatter = ticker.StrMethodFormatter('{x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)
plt.xlim(0, max(y_test.max(), y_pred.max()) * 1.1)
plt.ylim(0, max(y_test.max(), y_pred.max()) * 1.1)
plt.plot([0, y_test.max()], [0, y_test.max()], '#57658f', lw=2)

plt.subplot(1, 2, 2)
colors = ['#57658f' if i not in [6, 8, 12, 15] else '#ff9933' for i in range(len(x.head(16)))]
sns.barplot(x.head(16), y='variabili', x='coefficienti', orient='h', palette=colors)
plt.xlabel('Importance', fontsize = 12, fontstyle='italic')
plt.ylabel('Features', fontsize = 12, fontstyle='italic')
plt.title('Feature Importance', fontweight='bold')
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
custom_legend = plt.Line2D([], [], color='#ff9933', marker='s', markersize=10, linestyle='None', label='Our Variables')
plt.legend(handles=[custom_legend], loc='lower right', fontsize=10)

plt.tight_layout()
#plt.savefig('/Users/vincenzocamerlengo/Desktop/Data Science in Action/Unieuro Dataset-20240305/grafici/core_pred.png', dpi=900)
plt.show()

# %% [markdown]
# ### TV

# %%
tv = pd.read_csv('./Working Code/Datasets/tv1.csv') 
tv['DATA_INIZIO'] = pd.to_datetime(tv['DATA_INIZIO'])
tv['Year'] = tv['DATA_INIZIO'].dt.year
tv = tv[tv['Year'] != 2020].reset_index()
tv.drop('index', axis=1, inplace=True) 
X = tv[['PREZZO_PROMO', 'PREZZO_LISTINO', 'STOCK_PZ',
        'SCONTO_PERC', 'KPI_1',
        'KPI_2', 'KPI_3', 'KPI_4', 'KPI_5', 'QTA_storico',
        'FATTURATO_storico', 'DURATA_VOLANTINO_IN_GIORNI',
        'DISPLAY_SIZE', 'HD_QUALITY', 'OLED', 'SMART',
        'MFM', 'WCG', 'MINILED', 'SCONTO_PERC_MEDIO_VOLANTINO', 'Month_Redditivity',
        'SCONTO_PERC_MEDIO_NOME_CAMPAGNA', 'DATA_INIZIO']]
y = tv[['QTA', 'DATA_INIZIO']]

final_df = X

X_train = final_df[~(((final_df['DATA_INIZIO'].dt.month == 8) | (final_df['DATA_INIZIO'].dt.month == 9) | (final_df['DATA_INIZIO'].dt.month == 10)) & (final_df['DATA_INIZIO'].dt.year == 2023))]
X_test = final_df[((final_df['DATA_INIZIO'].dt.month == 8) | (final_df['DATA_INIZIO'].dt.month == 9) | (final_df['DATA_INIZIO'].dt.month == 10)) & (final_df['DATA_INIZIO'].dt.year == 2023)]

X_train.drop('DATA_INIZIO', axis=1, inplace=True)
X_test.drop('DATA_INIZIO', axis=1, inplace=True)

y_train = y[~(((y['DATA_INIZIO'].dt.month == 8) | (y['DATA_INIZIO'].dt.month == 9) | (y['DATA_INIZIO'].dt.month == 10)) & (y['DATA_INIZIO'].dt.year == 2023))]
y_test = y[((y['DATA_INIZIO'].dt.month == 8) | (y['DATA_INIZIO'].dt.month == 9) | (y['DATA_INIZIO'].dt.month == 10)) & (y['DATA_INIZIO'].dt.year == 2023)]
y_train.drop('DATA_INIZIO', axis=1, inplace=True)
y_test.drop('DATA_INIZIO', axis=1, inplace=True)

y_train = y_train.values
y_test = y_test.values
column_names = X_train.columns.tolist()
hyperparameters = {'subsample': 0.6, 'n_estimators': 300, 'min_child_weight': 2, 'max_depth': 5, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 0.6}

import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error

xgbr = xgb.XGBRegressor(random_state=69, **hyperparameters)
xgbr.fit(X_train, y_train)
y_pred = xgbr.predict(X_test)
y_pred = np.where(y_pred < 0, 0, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'RMSE = {rmse}')
# Out:
# RMSE = 174.26976030446818

# %%
var=[]
coeff=[]
for feature, coef in zip(column_names, xgbr.feature_importances_):
    var.append(feature)
    coeff.append(coef)
x = pd.DataFrame({'variabili':var, 'coefficienti':coeff})
x['coefficienti'] = x['coefficienti'].abs()
x['coefficienti'] = x['coefficienti']/x['coefficienti'].max()
x.sort_values(by='coefficienti', ascending=False, inplace=True)
x.reset_index(inplace=True)
x.drop('index', axis=1, inplace=True)

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
plt.scatter(y_test.flatten(), y_pred, color='#ff9933')
plt.title('Predictions', fontweight='bold')
plt.xlabel('True Values', fontsize = 12, fontstyle='italic')
plt.ylabel('Predicted Values', fontsize = 12, fontstyle='italic')
formatter = ticker.StrMethodFormatter('{x:,.0f}')
plt.gca().xaxis.set_major_formatter(formatter)
formatter = ticker.StrMethodFormatter('{x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)
plt.xlim(0, max(y_test.max(), y_pred.max()) * 1.1)
plt.ylim(0, max(y_test.max(), y_pred.max()) * 1.1)
plt.plot([0, y_test.max()], [0, y_test.max()], '#57658f', lw=2)

plt.subplot(1, 2, 2)
colors = ['#57658f' if i not in [6, 15] else '#ff9933' for i in range(len(x.head(16)))]
sns.barplot(x.head(16), y='variabili', x='coefficienti', orient='h', palette=colors)
plt.xlabel('Importance', fontsize = 12, fontstyle='italic')
plt.ylabel('Features', fontsize = 12, fontstyle='italic')
plt.title('Feature Importance', fontweight='bold')
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
custom_legend = plt.Line2D([], [], color='#ff9933', marker='s', markersize=10, linestyle='None', label='Our Variables')
plt.legend(handles=[custom_legend], loc='lower right', fontsize=10)

plt.tight_layout()
#plt.savefig('/Users/vincenzocamerlengo/Desktop/Data Science in Action/Unieuro Dataset-20240305/grafici/tv_pred.png', dpi=900)
plt.show()
